# %% [markdown]
# # Data types vs values
#
# * What is the value of `a`?
# * What is the type of `a`?

# %%
a = 2

# %%
a

# %%
type(a)

# %% [markdown]
# # Data types we've seen so far

# %%
type(2)

# %%
type(42.0)

# %%
type("Hello world!")

# %% [markdown]
# # Converting to an integer

# %%
int(42.0)

# %%
int("Hello world!")

# %%
"123" / 3

# %%
type("123")

# %%
int("123")

# %%
type(int("123"))

# %%
int("123") / 3

# %% [markdown]
# Under what circumstances would you actually need to do this? What does `input()` return?

# %%
returned_value = input()
type(returned_value)

# %%
returned_value = input()
returned_value / 3

# %%
returned_value = input()
int(returned_value) / 3

# %% [markdown]
# # English vs Python (so far)
#
# Based on everything you've seen so far, how does English and Python compare?

# %% [markdown]
# | English      | Python      |
# | ------------- | ------------- |
# | "Natural" language | "Formal" language |
# | Evolved naturally over time | Intentionally designed |
# | Sometimes unclear rules | Nearly or completely unambiguous |
# | Rely on contextual clues | Only one meaning, regardless of context |
# | Long essays/verbose | Short snippets/terse |
# | Lots of metaphors | Means exactly what it says |
# | Typically read from left->right, top->bottom | Can hop all over the place when reading |
# | Reasonably fast to read | Can take a while to read |
# | Small punctuation/spelling errors OK | Small errors cause complete failures |

# %% [markdown]
# # Debugging
#
# When your code didn't work, what did you do? How did you feel? How did you fix the problem?

# %%
3$3

# %% [markdown]
# # Activity
# * Complete term matching activity on Moodle
# * Not actually a quiz
# * Complete first without looking at the book
# * You can correct your answers as we discuss them
