# %%
# Ignore this for now
def f_print(ans):
    ans_type = type(ans).__name__
    print("Type: %s, Answer: %s" % (ans_type, ans))

# %%
a = (2 + 3) * 4
f_print(a)

# %%
b = 18 // 4 + 2
f_print(b)

# %%
c = 5 * (3 + 7)
f_print(c)

# %%
d = 18 / 4 + 2
f_print(d)

# %%
e = (10 - 3) / 2
f_print(e)

# %%
f = 7 + 2.0
f_print(f)

# %%
g = 2 + 3 * 4
f_print(g)

# %%
h = (2 + 3) * 4
f_print(h)

# %%
i = 10 / (2 + 3)
f_print(i)

# %%
j = 10 / 2 + 3
f_print(j)

# %%
k = 5 / 2 * 2
f_print(k)

# %%
l = 5 // 2 * 2
f_print(l)

# %%
m = 8 / 4 / 2
f_print(m)

# %%
n = 8 / (4 / 2)
f_print(n)
