# %%
5 % 3
# Out:
# 2

# %%
5 % 5
# Out:
# 0

# %%
42 % 5
# Out:
# 2

# %%
42 % 5 == 0
# Out:
# False

# %%
45 % 5
# Out:
# 0

# %%
45 % 5 == 0
# Out:
# True

# %%
type("True")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
6 == 8
# Out:
# False

# %%
first = "Apple"
second = 4
first == second
# Out:
# False

# %%
first = 5
second = 4
first == second
# Out:
# False

# %%
first = 4
second = 4
first == second
# Out:
# True

# %%
first = 4
second = 4
first >= second
# Out:
# True

# %%
first = 4
second = 4
first > second
# Out:
# False

# %%
first = 4
second = 4
first != second
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
4 == 4 and 4 == 3
# Out:
# False

# %%
4 == 4 or 4 == 3
# Out:
# True

# %%
4 == 4 or 4 == 4
# Out:
# True

# %%
4 == 4 and 4 == 4
# Out:
# True

# %%
4 == 3 or 4 == 3
# Out:
# False

# %%
4 == 3 and 4 == 3
# Out:
# False

# %%
6 and 4 > 2
# Out:
# True

# %%
not 4 == 4
# Out:
# False

# %%
not 2 > 4
# Out:
# True
