# %% [markdown]
# ---> COMPLETE PART **ONE** OF ASSIGNMENT 09-24

# %% [markdown]
# # The print function
#
# When you *evaluate* an *expression*, the result is displayed.

# %%
n = 2
n + 1
# Out:
# 3

# %% [markdown]
# But if you *evaluate* more than one *expression*, only the value of the last one is displayed.

# %%
n + 2
n + 3
# Out:
# 5

# %% [markdown]
# To display more than one value, you can use the `print` function.

# %%
print(n+2)
print(n+3)
# Out:
# 4
# 5

# %% [markdown]
# It also works with strings.

# %%
"This is"
"a string"
# Out:
# 'a string'

# %%
print("This is")
print("a string")
# Out:
# This is
# a string

# %% [markdown]
# You can also use a sequence of expressions separated by commas.

# %%
print("This is", "a string")
# Out:
# This is a string

# %% [markdown]
# Notice that the `print` function puts a space between the values, while concatenation does not.

# %%
print("This is" + "a string")
# Out:
# This isa string

# %% [markdown]
# This might not always be helpful as we see below.

# %%
digit1 = 4
digit2 = 8
print("Your number is", str(digit1), str(digit2), ".")
# Out:
# Your number is 4 8 .

# %% [markdown]
# In this case, concatenation works better.

# %%
print("Your number is", str(digit1) + str(digit2) + ".")
# Out:
# Your number is 48.

# %% [markdown]
# ---> COMPLETE PART **TWO** OF ASSIGNMENT 09-24

# %% [markdown]
# # Arguments
#
# When you call a function, the expression in parenthesis is called an **argument**.
#
# We've only talked about giving a function one argument like below:

# %%
float("1.0")
# Out:
# 1.0

# %% [markdown]
# But some functions take two, like `math.pow`.

# %%
import math
math.pow(5,2)
# Out:
# 25.0

# %% [markdown]
# Some can take additional arguments that are optional:

# %%
round(math.pi)
# Out:
# 3

# %%
round(math.pi, 3)
# Out:
# 3.142

# %%
round(3, math.pi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 round(3, math.pi)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# Some functions can take any number of arguments, like `print`.

# %%
print('Any', 'number', 'of', 'arguments')

# %%
print('Any ' + 'number ' + 'of ' + 'arguments')

# %% [markdown]
# If you call a function and provide too many arguments, that's a `TypeError`.

# %%
float('123.0', 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 float('123.0', 2)
#
# TypeError: float expected at most 1 argument, got 2

# %% [markdown]
# If you provide too few arguments, that's also a `TypeError`.

# %%
math.pow(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 math.pow(2)
#
# TypeError: pow expected 2 arguments, got 1

# %% [markdown]
# And if you provide an argument with a type the function can't handle, that's a `TypeError`, too.

# %%
math.sqrt('123')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 math.sqrt('123')
#
# TypeError: must be real number, not str

# %% [markdown]
# This kind of checking can be annoying when you are getting started, but it helps you detect and correct errors.

# %% [markdown]
# ---> COMPLETE PART **THREE** OF ASSIGNMENT 09-24
